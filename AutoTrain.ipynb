# %%
from google.colab import userdata

#@title 🤗 AutoTrain
#@markdown In order to use this colab
#@markdown - Enter your [Hugging Face Write Token](https://huggingface.co/settings/tokens)
#@markdown - Enter your [ngrok auth token](https://dashboard.ngrok.com/get-started/your-authtoken)
huggingface_token = userdata.get('HF_TOKEN') # @param {type:"string"}
ngrok_token = userdata.get('NGROK_TOKEN') # @param {type:"string"}

#@markdown
#@markdown - Attach appropriate accelerator `Runtime > Change runtime type > Hardware accelerator`
#@markdown - click `Runtime > Run all`
#@markdown - Follow the link to access the UI
#@markdown - Training happens inside this Google Colab
#@markdown - report issues / feature requests [here](https://github.com/huggingface/autotrain-advanced/issues)

import os
os.environ["HF_TOKEN"] = str(huggingface_token)
os.environ["NGROK_AUTH_TOKEN"] = str(ngrok_token)
os.environ["AUTOTRAIN_LOCAL"] = "1"

# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain app --share
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# > INFO    Authenticating user...
# > WARNING Parameters not supplied by user and set to default: seed, model_max_length, lr, batch_size, model_ref, token, username, warmup_ratio, text_column, project_name, lora_dropout, merge_adapter, weight_decay, use_flash_attention_2, rejected_text_column, gradient_accumulation, logging_steps, prompt_text_column, apply_chat_template, push_to_hub, disable_gradient_checkpointing, scheduler, save_strategy, dpo_beta, optimizer, lora_r, model, valid_split, save_total_limit, train_split, repo_id, data_path, add_eos_token, lora_alpha, max_grad_norm, evaluation_strategy, trainer, auto_find_batch_size
# > WARNING Parameters not supplied by user and set to default: seed, lr, batch_size, push_to_hub, token, scheduler, target_column, username, save_strategy, optimizer, warmup_ratio, valid_split, model, train_split, save_total_limit, text_column, project_name, log, repo_id, weight_decay, data_path, max_seq_length, epochs, max_grad_norm, evaluation_strategy, gradient_accumulation, auto_find_batch_size, logging_steps
# > WARNING Parameters not supplied by user and set to default: seed, image_column, lr, batch_size, push_to_hub, token, scheduler, target_column, username, save_strategy, optimizer, warmup_ratio, valid_split, model, train_split, save_total_limit, log, project_name, repo_id, weight_decay, data_path, epochs, max_grad_norm, evaluation_strategy, gradient_accumulation, auto_find_batch_size, logging_steps
# > WARNING Parameters not supplied by user and set to default: seed, max_target_length, lr, batch_size, token, target_column, username, warmup_ratio, peft, text_column, project_name, lora_dropout, gradient_accumulation, logging_steps, evaluation_strategy, push_to_hub, scheduler, save_strategy, target_modules, optimizer, lora_r, valid_split, model, train_split, save_total_limit, quantization, repo_id, data_path, lora_alpha, epochs, max_seq_length, max_grad_norm, weight_decay, auto_find_batch_size
# > WARNING Parameters not supplied by user and set to default: seed, push_to_hub, token, id_column, username, valid_split, time_limit, model, train_split, project_name, numerical_columns, num_trials, task, repo_id, target_columns, data_path, categorical_columns
# > WARNING Parameters not supplied by user and set to default: seed, num_validation_images, revision, prior_generation_precision, scale_lr, sample_batch_size, class_labels_conditioning, token, tokenizer, username, checkpointing_steps, resume_from_checkpoint, center_crop, validation_images, project_name, class_image_path, image_path, local_rank, bf16, adam_beta2, xl, checkpoints_total_limit, validation_epochs, adam_weight_decay, adam_epsilon, num_class_images, tokenizer_max_length, push_to_hub, validation_prompt, scheduler, prior_preservation, num_cycles, allow_tf32, model, text_encoder_use_attention_mask, pre_compute_text_embeddings, logging, dataloader_num_workers, repo_id, lr_power, epochs, warmup_steps, max_grad_norm, prior_loss_weight, rank, adam_beta1, class_prompt
# > WARNING Parameters not supplied by user and set to default: seed, lr, batch_size, push_to_hub, token, scheduler, save_strategy, username, optimizer, warmup_ratio, tags_column, valid_split, model, train_split, save_total_limit, log, project_name, tokens_column, repo_id, weight_decay, data_path, max_seq_length, epochs, max_grad_norm, evaluation_strategy, gradient_accumulation, auto_find_batch_size, logging_steps
# > INFO    AutoTrain Public URL: NgrokTunnel: "https://47a3-34-143-154-24.ngrok-free.app" -> "http://localhost:7860"
# > INFO    Please wait for the app to load...
# > INFO    ***
# INFO:     Started server process [1208]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:7860 (Press CTRL+C to quit)
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET / HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /logo.png HTTP/1.1" 200 OK
# > INFO    Task: llm:sft
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Asft HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Asft HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /help/task_info HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Ageneric HTTP/1.1" 200 OK
# > INFO    Task: llm:generic
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Ageneric HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Adpo HTTP/1.1" 200 OK
# > INFO    Task: llm:dpo
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Adpo HTTP/1.1" 200 OK
# > INFO    Task: llm:reward
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Areward HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Areward HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/text-classification HTTP/1.1" 200 OK
# > INFO    Task: text-classification
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/text-classification HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Asft HTTP/1.1" 200 OK
# > INFO    Task: llm:sft
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Asft HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Task: llm:generic
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Ageneric HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Ageneric HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Task: llm:sft
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /params/llm%3Asft HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /model_choices/llm%3Asft HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /accelerators HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# > INFO    Running jobs: []
# INFO:     2a01:e0a:9dc:46e0:40d9:3931:292c:1022:0 - "GET /is_model_training HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Finished server process [1208]
# ERROR:    Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/starlette/routing.py", line 686, in lifespan
#     await receive()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/lifespan/on.py", line 139, in receive
#     return await self.receive_queue.get()
#   File "/usr/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# ^C
